# %%
# !ls
# Out:
# 2017 NEISS Data Highlights.pdf        NEISS.ipynb
# 2018-NEISS-CPSC-only-CodingManual.pdf neiss2017.tsv
# 2018ComparabilityTable.pdf            neiss_fmt.txt

# %%
import pandas as pd

# %matplotlib inline

# %%
#Show me the first 5 rows of this file
# !head -n 5 neiss2017.tsv
# Out:
# "CPSC_Case_Number"	"Treatment_Date"	"Age"	"Sex"	"Race"	"Other_Race"	"Body_Part"	"Diagnosis"	"Other_Diagnosis"	"Disposition"	"Location"	"Fire_Involvement"	"Product_1"	"Product_2"	"Narrative_1"	"Narrative_2"	"Stratum"	"PSU"	"Weight"
# 170100733	01/01/2017	21	1	1		75	62		1	1	0	1207	0	21YOM WAS BOXING WITH FRIEND WHILE DRINKING AND GOT PUNCHED IN THE FACE	. BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXICATION	S	46	77.6641
# 170100734	01/01/2017	71	1	1		31	53		1	5	0	1807	0	71YOM FELL ON FLOOR IN BATHROOM. DX RIB CONTUSION		S	46	77.6641
# 170100735	01/01/2017	16	1	1		33	51		1	1	0	676	342	16YOM TRIPPED OVER A RUG AND FELL INTO A BURNING FIREPLACE	DX BURNS INVOLVING LESS THAN 10% OF BODY SURFACE, FOREARM	S	46	77.6641
# 170100737	01/01/2017	55	2	1		75	62		1	1	0	620	0	55YOF WAS STANDING ON A STEP STOOL AND LOST FOOTING AND FELL. DX CLOSED	HEAD INJURY	S	46	77.6641

# %%
#\t means 'the tab charater'
# \n means 'a new line'
# sep=means this is what seperated our stuff'
# encoding=says this is the encoding i want to use

df = pd.read_csv("neiss2017.tsv",sep='\t',encoding='Latin-1', na_values=[0])
df.head()
# Out:
# /Users/kosmas/.pyenv/versions/3.7.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   CPSC_Case_Number Treatment_Date Age  Sex  Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21    1   1.0        NaN       75.0
# 1        170100734     01/01/2017  71    1   1.0        NaN       31.0
# 2        170100735     01/01/2017  16    1   1.0        NaN       33.0
# 3        170100737     01/01/2017  55    2   1.0        NaN       75.0
# 4        170100740     01/01/2017  86    2   1.0        NaN       79.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               0.0
# 1       53.0             NaN          1.0       5.0               0.0
# ...

# %%
df.shape
# Out:
# (386907, 19)

# %%
df.tail(2)
# Out:
#        CPSC_Case_Number Treatment_Date  Age  Sex  Race Other_Race  Body_Part  \
# 386905        180309765     12/31/2017  202    1   1.0        NaN       75.0
# 386906        180309766     12/31/2017    2    2   1.0        NaN       85.0
#
#         Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 386905       57.0             NaN          4.0       1.0               0.0
# 386906       68.0             NaN          4.0       1.0               0.0
#
#         Product_1  Product_2  \
# 386905     1842.0        0.0
# 386906     1931.0        0.0
#
#                                               Narrative_1 Narrative_2 Stratum  \
# 386905  2MO M DAD FELL ON STAIRS WHILE HOLDING BABY;DX...         NaN       C
# 386906  2YR F GOT INTO DAD'S ***;DX ACCIDENTAL DRUG IN...         NaN       C
#
#          PSU  Weight
# 386905  20.0   4.757
# 386906  20.0   4.757

# %%
df.dtypes
# Out:
# CPSC_Case_Number     object
# Treatment_Date       object
# Age                  object
# Sex                   int64
# Race                float64
# Other_Race           object
# Body_Part           float64
# Diagnosis           float64
# Other_Diagnosis      object
# Disposition         float64
# Location            float64
# Fire_Involvement    float64
# Product_1           float64
# Product_2           float64
# Narrative_1          object
# Narrative_2          object
# Stratum              object
# PSU                 float64
# Weight              float64
# dtype: object

# %%
df.Sex
# Out:
# 0         1
# 1         1
# 2         1
# 3         2
# 4         2
# 5         1
# 6         1
# 7         1
# 8         1
# 9         2
# 10        2
# 11        1
# 12        2
# 13        2
# 14        1
# 15        2
# 16        2
# 17        2
# 18        2
# 19        2
# 20        2
# 21        1
# 22        1
# 23        1
# 24        1
# 25        1
# 26        2
# 27        2
# 28        1
# 29        2
#          ..
# 386877    1
# 386878    2
# 386879    2
# 386880    1
# 386881    2
# 386882    2
# 386883    2
# 386884    1
# 386885    2
# 386886    1
# 386887    1
# 386888    1
# 386889    1
# 386890    2
# 386891    2
# 386892    1
# 386893    2
# 386894    1
# 386895    1
# 386896    1
# 386897    1
# 386898    2
# 386899    2
# 386900    2
# 386901    1
# 386902    2
# 386903    2
# 386904    1
# 386905    1
# 386906    2
# Name: Sex, Length: 386907, dtype: int64

# %%
df.Sex.value_counts()
# Out:
# 1    208695
# 2    178203
# 0         8
# 8         1
# Name: Sex, dtype: int64

# %%
# 1 - Male
# 2 - Female
# 0 - Not recorded
# 8 - ?????

df.Sex.replace({
    1: 'Male',
    2: 'Female',
    0: 'Not recorded'
})
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3         Female
# 4         Female
# 5           Male
# 6           Male
# 7           Male
# 8           Male
# 9         Female
# 10        Female
# 11          Male
# 12        Female
# 13        Female
# 14          Male
# 15        Female
# 16        Female
# 17        Female
# 18        Female
# 19        Female
# 20        Female
# 21          Male
# 22          Male
# 23          Male
# 24          Male
# 25          Male
# 26        Female
# 27        Female
# 28          Male
# 29        Female
#            ...
# 386877      Male
# 386878    Female
# 386879    Female
# 386880      Male
# 386881    Female
# 386882    Female
# 386883    Female
# 386884      Male
# 386885    Female
# 386886      Male
# 386887      Male
# 386888      Male
# 386889      Male
# 386890    Female
# 386891    Female
# 386892      Male
# 386893    Female
# 386894      Male
# 386895      Male
# 386896      Male
# 386897      Male
# ...

# %%
df.head()
# Out:
#   CPSC_Case_Number Treatment_Date Age  Sex  Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21    1   1.0        NaN       75.0
# 1        170100734     01/01/2017  71    1   1.0        NaN       31.0
# 2        170100735     01/01/2017  16    1   1.0        NaN       33.0
# 3        170100737     01/01/2017  55    2   1.0        NaN       75.0
# 4        170100740     01/01/2017  86    2   1.0        NaN       79.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               0.0
# 1       53.0             NaN          1.0       5.0               0.0
# 2       51.0             NaN          1.0       1.0               0.0
# 3       62.0             NaN          1.0       1.0               0.0
# 4       58.0             NaN          1.0       1.0               0.0
#
#    Product_1  Product_2                                        Narrative_1  \
# ...

# %%
df['Sex'] = df.Sex.replace({
    1: 'Male',
    2: 'Female',
    0: 'Not recorded'
})

# %%
df.head()
# Out:
#   CPSC_Case_Number Treatment_Date Age     Sex  Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21    Male   1.0        NaN       75.0
# 1        170100734     01/01/2017  71    Male   1.0        NaN       31.0
# 2        170100735     01/01/2017  16    Male   1.0        NaN       33.0
# 3        170100737     01/01/2017  55  Female   1.0        NaN       75.0
# 4        170100740     01/01/2017  86  Female   1.0        NaN       79.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               0.0
# 1       53.0             NaN          1.0       5.0               0.0
# 2       51.0             NaN          1.0       1.0               0.0
# 3       62.0             NaN          1.0       1.0               0.0
# 4       58.0             NaN          1.0       1.0               0.0
#
#    Product_1  Product_2                                        Narrative_1  \
# ...

# %%
df.Sex.value_counts()
# Out:
# Male            208695
# Female          178203
# Not recorded         8
# 8                    1
# Name: Sex, dtype: int64

# %%
#Just show me the row that sex is 8
df.Sex == 8
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 386877    False
# 386878    False
# 386879    False
# 386880    False
# 386881    False
# 386882    False
# 386883    False
# 386884    False
# 386885    False
# 386886    False
# 386887    False
# 386888    False
# 386889    False
# 386890    False
# 386891    False
# 386892    False
# 386893    False
# 386894    False
# 386895    False
# 386896    False
# 386897    False
# 386898    False
# 386899    False
# 386900    False
# ...

# %%
df[df.Sex == 8]
# Out:
#        CPSC_Case_Number Treatment_Date Age Sex   Race Other_Race  Body_Part  \
# 160878      ;CONCUSSION            NaN   C   8  4.757        NaN        NaN
#
#         Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 160878        NaN             NaN          NaN       NaN               NaN
#
#         Product_1  Product_2 Narrative_1 Narrative_2 Stratum  PSU  Weight
# 160878        NaN        NaN         NaN         NaN     NaN  NaN     NaN

# %%
# Is a treatment date empty?
# .isna() or .isnull()

df.Treatment_Date.isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 386877    False
# 386878    False
# 386879    False
# 386880    False
# 386881    False
# 386882    False
# 386883    False
# 386884    False
# 386885    False
# 386886    False
# 386887    False
# 386888    False
# 386889    False
# 386890    False
# 386891    False
# 386892    False
# 386893    False
# 386894    False
# 386895    False
# 386896    False
# 386897    False
# 386898    False
# 386899    False
# 386900    False
# ...

# %%
df.Treatment_Date.isna.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6f87bad3459c> in <module>
# ----> 1 df.Treatment_Date.isna.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
(df.Sex == 'Male').sum()

# %%
df.dropna(subset=['Treatment_Date'])

# %%
df = df.dropna(subset=['Treatment_Date'])

# %%
#df.dropna(subset=['Treatment_Date'])

# %%
df.Age.min()

# %%
#df.Age.astype(int).min() ??????

# %%
#df.Age.astype(int).median() ??????

# %%
df.Age.describe()
# Out:
# count     386907
# unique       261
# top            2
# freq       12099
# Name: Age, dtype: int64

# %%
df.Age.hist(bins=50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-dc6419d8f42e> in <module>
# ----> 1 df.Age.hist(bins=50)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2475         values = self.dropna().values
#    2476
# -> 2477         ax.hist(values, bins=bins, **kwds)
#    2478         ax.grid(grid)
#    2479         axes = np.array([ax])
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
(df.Age >= 200).sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-7e6bb1fa52a8> in <module>
# ----> 1 (df.Age >= 200).sum()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
# ...

# %%
df = df[df.Age < 200]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-fb3064f06b29> in <module>
# ----> 1 df = df[df.Age < 200]
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
# ...

# %%
df.Race
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
# 5         1.0
# 6         1.0
# 7         1.0
# 8         1.0
# 9         0.0
# 10        0.0
# 11        0.0
# 12        0.0
# 13        0.0
# 14        0.0
# 15        0.0
# 16        0.0
# 17        0.0
# 18        0.0
# 19        0.0
# 20        0.0
# 21        0.0
# 22        0.0
# 23        0.0
# 24        0.0
# 25        0.0
# 26        0.0
# 27        0.0
# 28        0.0
# 29        0.0
#          ...
# 386877    0.0
# 386878    1.0
# 386879    3.0
# 386880    1.0
# 386881    1.0
# 386882    1.0
# 386883    0.0
# 386884    0.0
# 386885    3.0
# 386886    1.0
# 386887    1.0
# 386888    1.0
# 386889    1.0
# 386890    2.0
# 386891    1.0
# 386892    1.0
# 386893    1.0
# 386894    1.0
# 386895    1.0
# 386896    1.0
# 386897    1.0
# 386898    1.0
# 386899    1.0
# 386900    1.0
# 386901    2.0
# 386902    1.0
# 386903    2.0
# 386904    1.0
# 386905    1.0
# 386906    1.0
# ...

# %%
df.Race.replace({
    1: 'White',
    2: 'Black',
    3: 'Other',
    4: 'Asian',
    5: 'American Indian',
    6: 'Pacific Islander',
    0: 'Not Stated'
})
# Out:
# 0              White
# 1              White
# 2              White
# 3              White
# 4              White
# 5              White
# 6              White
# 7              White
# 8              White
# 9         Not Stated
# 10        Not Stated
# 11        Not Stated
# 12        Not Stated
# 13        Not Stated
# 14        Not Stated
# 15        Not Stated
# 16        Not Stated
# 17        Not Stated
# 18        Not Stated
# 19        Not Stated
# 20        Not Stated
# 21        Not Stated
# 22        Not Stated
# 23        Not Stated
# 24        Not Stated
# 25        Not Stated
# 26        Not Stated
# 27        Not Stated
# 28        Not Stated
# 29        Not Stated
#              ...
# 386877    Not Stated
# 386878         White
# 386879         Other
# 386880         White
# 386881         White
# 386882         White
# 386883    Not Stated
# 386884    Not Stated
# 386885         Other
# 386886         White
# 386887         White
# 386888         White
# ...

# %%
df.head()
# Out:
#   CPSC_Case_Number Treatment_Date Age     Sex  Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21    Male   1.0        NaN       75.0
# 1        170100734     01/01/2017  71    Male   1.0        NaN       31.0
# 2        170100735     01/01/2017  16    Male   1.0        NaN       33.0
# 3        170100737     01/01/2017  55  Female   1.0        NaN       75.0
# 4        170100740     01/01/2017  86  Female   1.0        NaN       79.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               0.0
# 1       53.0             NaN          1.0       5.0               0.0
# 2       51.0             NaN          1.0       1.0               0.0
# 3       62.0             NaN          1.0       1.0               0.0
# 4       58.0             NaN          1.0       1.0               0.0
#
#    Product_1  Product_2                                        Narrative_1  \
# ...

# %%
df['Race'] = df.Race.replace({
    1: 'White',
    2: 'Black',
    3: 'Other',
    4: 'Asian',
    5: 'American Indian',
    6: 'Pacific Islander',
    0: 'Not Stated'
})

# %%
df.head(2)
# Out:
#   CPSC_Case_Number Treatment_Date Age   Sex   Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21  Male  White        NaN       75.0
# 1        170100734     01/01/2017  71  Male  White        NaN       31.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               0.0
# 1       53.0             NaN          1.0       5.0               0.0
#
#    Product_1  Product_2                                        Narrative_1  \
# 0     1207.0        0.0  21YOM WAS BOXING WITH FRIEND WHILE DRINKING AN...
# 1     1807.0        0.0  71YOM FELL ON FLOOR IN BATHROOM. DX RIB CONTUSION
#
#                                          Narrative_2 Stratum   PSU   Weight
# 0  . BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXIC...       S  46.0  77.6641
# 1                                                NaN       S  46.0  77.6641

# %%
df.Race.value_counts()
# Out:
# White               160527
# Not Stated          143677
# Black                55144
# Other                21193
# Asian                 4714
# American Indian       1234
# Pacific Islander       417
# 4.757                    1
# Name: Race, dtype: int64

# %%
df.Race.value_counts().sort_values().plot(kind='barh')

# %%
df.Race.value_counts(normalize=True)
# Out:
# White               0.414898
# Not Stated          0.371348
# Black               0.142525
# Other               0.054775
# Asian               0.012184
# American Indian     0.003189
# Pacific Islander    0.001078
# 4.757               0.000003
# Name: Race, dtype: float64

# %%
df.Sex.value_counts(normalize=True)
# Out:
# Male            0.539393
# Female          0.460584
# Not recorded    0.000021
# 8               0.000003
# Name: Sex, dtype: float64

# %%
df.Other_Race.value_counts()
# Out:
# HISPANIC           17565
# UNKNOWN             2515
# MULTI-RACIAL        2334
# HISP                 816
# SOMALI               449
# NS                   312
# UNKN                 140
# NEPALI                51
# BIRACIAL              44
# MULTIRACIAL           34
# MULTI RACIAL          24
# ARAB                  17
# NON HISPANIC          15
# MEXICAN               14
# PUERTO RICAN          13
# DO NOT KNOW           13
# DECLINE               12
# `                     11
# UNK                   10
# HISPAINC               8
# SPANISH                8
# DECLINED               7
# MANDARIN               6
# HISAPNIC               6
# HISPANCI               6
# FULANI                 5
# TURKISH                4
# JAPANESE               4
# LAO                    4
# N/S                    4
#                    ...
# ``                     1
# HISPANICX              1
# CAMBODIAN              1
# HIPANI                 1
# HS[PANIC               1
# DONOT KNOW             1
# ...

# %%
import numpy as np

df.Other_Race.replace("NS", np.nan)
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
#             ...
# 386877         NaN
# 386878         NaN
# 386879    HISPANIC
# 386880         NaN
# 386881         NaN
# 386882         NaN
# 386883         NaN
# 386884         NaN
# 386885    HISPANIC
# 386886         NaN
# 386887         NaN
# 386888         NaN
# 386889         NaN
# 386890         NaN
# 386891         NaN
# 386892         NaN
# ...
