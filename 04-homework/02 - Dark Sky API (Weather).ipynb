# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
response = requests.get('https://api.darksky.net/forecast/9876b3ab257379b93910aa171d94a5d1/23.113592, -82.366592')
cuba = response.json()
cuba
# Out:
# {'latitude': 23.113592,
#  'longitude': -82.366592,
#  'timezone': 'America/Havana',
#  'currently': {'time': 1560206391,
#   'summary': 'Light Rain',
#   'icon': 'rain',
#   'nearestStormDistance': 0,
#   'precipIntensity': 0.0177,
#   'precipIntensityError': 0.0212,
#   'precipProbability': 0.88,
#   'precipType': 'rain',
#   'temperature': 87.46,
#   'apparentTemperature': 99.47,
#   'dewPoint': 77.01,
#   'humidity': 0.71,
#   'pressure': 1015.29,
#   'windSpeed': 3.84,
#   'windGust': 6.89,
#   'windBearing': 143,
#   'cloudCover': 0.74,
#   'uvIndex': 1,
#   'visibility': 9.03,
#   'ozone': 298.88},
#  'minutely': {'summary': 'Possible light rain for the hour.',
#   'icon': 'rain',
#   'data': [{'time': 1560206340,
#     'precipIntensity': 0.016,
#     'precipIntensityError': 0.017,
#     'precipProbability': 0.93,
#     'precipType': 'rain'},
#    {'time': 1560206400,
#     'precipIntensity': 0.018,
#     'precipIntensityError': 0.022,
#     'precipProbability': 0.87,
#     'precipType': 'rain'},
#    {'time': 1560206460,
#     'precipIntensity': 0.02,
#     'precipIntensityError': 0.025,
#     'precipProbability': 0.82,
#     'precipType': 'rain'},
#    {'time': 1560206520,
#     'precipIntensity': 0.022,
#     'precipIntensityError': 0.028,
#     'precipProbability': 0.74,
#     'precipType': 'rain'},
#    {'time': 1560206580,
#     'precipIntensity': 0.023,
#     'precipIntensityError': 0.032,
#     'precipProbability': 0.7,
#     'precipType': 'rain'},
#    {'time': 1560206640,
#     'precipIntensity': 0.026,
#     'precipIntensityError': 0.035,
#     'precipProbability': 0.65,
#     'precipType': 'rain'},
#    {'time': 1560206700,
#     'precipIntensity': 0.026,
#     'precipIntensityError': 0.034,
#     'precipProbability': 0.62,
#     'precipType': 'rain'},
#    {'time': 1560206760,
#     'precipIntensity': 0.028,
#     'precipIntensityError': 0.037,
#     'precipProbability': 0.6,
#     'precipType': 'rain'},
#    {'time': 1560206820,
#     'precipIntensity': 0.032,
#     'precipIntensityError': 0.041,
#     'precipProbability': 0.58,
#     'precipType': 'rain'},
#    {'time': 1560206880,
#     'precipIntensity': 0.032,
#     'precipIntensityError': 0.042,
#     'precipProbability': 0.57,
#     'precipType': 'rain'},
#    {'time': 1560206940,
#     'precipIntensity': 0.034,
#     'precipIntensityError': 0.044,
#     'precipProbability': 0.55,
#     'precipType': 'rain'},
#    {'time': 1560207000,
#     'precipIntensity': 0.035,
#     'precipIntensityError': 0.046,
#     'precipProbability': 0.54,
#     'precipType': 'rain'},
#    {'time': 1560207060,
#     'precipIntensity': 0.036,
#     'precipIntensityError': 0.05,
#     'precipProbability': 0.53,
#     'precipType': 'rain'},
#    {'time': 1560207120,
#     'precipIntensity': 0.038,
#     'precipIntensityError': 0.051,
#     'precipProbability': 0.54,
#     'precipType': 'rain'},
#    {'time': 1560207180,
#     'precipIntensity': 0.038,
#     'precipIntensityError': 0.05,
#     'precipProbability': 0.55,
#     'precipType': 'rain'},
#    {'time': 1560207240,
#     'precipIntensity': 0.039,
#     'precipIntensityError': 0.051,
#     'precipProbability': 0.52,
#     'precipType': 'rain'},
#    {'time': 1560207300,
#     'precipIntensity': 0.039,
#     'precipIntensityError': 0.049,
#     'precipProbability': 0.52,
#     'precipType': 'rain'},
#    {'time': 1560207360,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.055,
#     'precipProbability': 0.52,
#     'precipType': 'rain'},
#    {'time': 1560207420,
#     'precipIntensity': 0.039,
#     'precipIntensityError': 0.048,
#     'precipProbability': 0.5,
#     'precipType': 'rain'},
#    {'time': 1560207480,
#     'precipIntensity': 0.04,
#     'precipIntensityError': 0.057,
#     'precipProbability': 0.49,
#     'precipType': 'rain'},
#    {'time': 1560207540,
#     'precipIntensity': 0.038,
#     'precipIntensityError': 0.051,
#     'precipProbability': 0.48,
#     'precipType': 'rain'},
#    {'time': 1560207600,
#     'precipIntensity': 0.04,
#     'precipIntensityError': 0.053,
#     'precipProbability': 0.48,
#     'precipType': 'rain'},
#    {'time': 1560207660,
#     'precipIntensity': 0.04,
#     'precipIntensityError': 0.054,
#     'precipProbability': 0.46,
#     'precipType': 'rain'},
#    {'time': 1560207720,
#     'precipIntensity': 0.04,
#     'precipIntensityError': 0.057,
#     'precipProbability': 0.45,
#     'precipType': 'rain'},
#    {'time': 1560207780,
#     'precipIntensity': 0.039,
#     'precipIntensityError': 0.05,
#     'precipProbability': 0.43,
#     'precipType': 'rain'},
#    {'time': 1560207840,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.062,
#     'precipProbability': 0.42,
#     'precipType': 'rain'},
#    {'time': 1560207900,
#     'precipIntensity': 0.04,
#     'precipIntensityError': 0.058,
#     'precipProbability': 0.42,
#     'precipType': 'rain'},
#    {'time': 1560207960,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.057,
#     'precipProbability': 0.41,
#     'precipType': 'rain'},
#    {'time': 1560208020,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.058,
#     'precipProbability': 0.4,
#     'precipType': 'rain'},
#    {'time': 1560208080,
#     'precipIntensity': 0.04,
#     'precipIntensityError': 0.059,
#     'precipProbability': 0.39,
#     'precipType': 'rain'},
#    {'time': 1560208140,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.062,
#     'precipProbability': 0.37,
#     'precipType': 'rain'},
#    {'time': 1560208200,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.062,
#     'precipProbability': 0.35,
#     'precipType': 'rain'},
#    {'time': 1560208260,
#     'precipIntensity': 0.042,
#     'precipIntensityError': 0.061,
#     'precipProbability': 0.34,
#     'precipType': 'rain'},
#    {'time': 1560208320,
#     'precipIntensity': 0.043,
#     'precipIntensityError': 0.063,
#     'precipProbability': 0.34,
#     'precipType': 'rain'},
#    {'time': 1560208380,
#     'precipIntensity': 0.04,
#     'precipIntensityError': 0.06,
#     'precipProbability': 0.32,
#     'precipType': 'rain'},
#    {'time': 1560208440,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.059,
#     'precipProbability': 0.32,
#     'precipType': 'rain'},
#    {'time': 1560208500,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.065,
#     'precipProbability': 0.3,
#     'precipType': 'rain'},
#    {'time': 1560208560,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.062,
#     'precipProbability': 0.3,
#     'precipType': 'rain'},
#    {'time': 1560208620,
#     'precipIntensity': 0.041,
#     'precipIntensityError': 0.062,
#     'precipProbability': 0.28,
#     'precipType': 'rain'},
#    {'time': 1560208680,
#     'precipIntensity': 0.042,
#     'precipIntensityError': 0.063,
#     'precipProbability': 0.28,
#     'precipType': 'rain'},
#    {'time': 1560208740,
#     'precipIntensity': 0.043,
#     'precipIntensityError': 0.065,
#     'precipProbability': 0.27,
#     'precipType': 'rain'},
#    {'time': 1560208800,
#     'precipIntensity': 0.045,
#     'precipIntensityError': 0.069,
#     'precipProbability': 0.27,
#     'precipType': 'rain'},
#    {'time': 1560208860,
#     'precipIntensity': 0.045,
#     'precipIntensityError': 0.068,
#     'precipProbability': 0.25,
#     'precipType': 'rain'},
#    {'time': 1560208920,
#     'precipIntensity': 0.043,
#     'precipIntensityError': 0.068,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1560208980,
#     'precipIntensity': 0.045,
#     'precipIntensityError': 0.068,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1560209040,
#     'precipIntensity': 0.045,
#     'precipIntensityError': 0.066,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1560209100,
#     'precipIntensity': 0.044,
#     'precipIntensityError': 0.068,
#     'precipProbability': 0.23,
#     'precipType': 'rain'},
#    {'time': 1560209160,
#     'precipIntensity': 0.043,
#     'precipIntensityError': 0.067,
#     'precipProbability': 0.22,
#     'precipType': 'rain'},
#    {'time': 1560209220,
#     'precipIntensity': 0.045,
#     'precipIntensityError': 0.067,
#     'precipProbability': 0.21,
#     'precipType': 'rain'},
#    {'time': 1560209280,
#     'precipIntensity': 0.043,
#     'precipIntensityError': 0.067,
#     'precipProbability': 0.21,
#     'precipType': 'rain'},
#    {'time': 1560209340,
#     'precipIntensity': 0.047,
#     'precipIntensityError': 0.071,
#     'precipProbability': 0.2,
#     'precipType': 'rain'},
#    {'time': 1560209400,
#     'precipIntensity': 0.042,
#     'precipIntensityError': 0.067,
#     'precipProbability': 0.2,
#     'precipType': 'rain'},
#    {'time': 1560209460,
#     'precipIntensity': 0.044,
#     'precipIntensityError': 0.066,
#     'precipProbability': 0.19,
#     'precipType': 'rain'},
#    {'time': 1560209520,
#     'precipIntensity': 0.042,
#     'precipIntensityError': 0.061,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1560209580,
#     'precipIntensity': 0.044,
#     'precipIntensityError': 0.068,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1560209640,
#     'precipIntensity': 0.047,
#     'precipIntensityError': 0.073,
#     'precipProbability': 0.17,
#     'precipType': 'rain'},
#    {'time': 1560209700,
#     'precipIntensity': 0.047,
#     'precipIntensityError': 0.08,
#     'precipProbability': 0.17,
#     'precipType': 'rain'},
#    {'time': 1560209760,
#     'precipIntensity': 0.048,
#     'precipIntensityError': 0.083,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1560209820,
#     'precipIntensity': 0.051,
#     'precipIntensityError': 0.108,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1560209880,
#     'precipIntensity': 0.045,
#     'precipIntensityError': 0.071,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1560209940,
#     'precipIntensity': 0.044,
#     'precipIntensityError': 0.066,
#     'precipProbability': 0.15,
#     'precipType': 'rain'}]},
#  'hourly': {'summary': 'Light rain tomorrow evening.',
#   'icon': 'rain',
#   'data': [{'time': 1560204000,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0182,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 88.37,
#     'apparentTemperature': 100.68,
#     'dewPoint': 76.89,
#     'humidity': 0.69,
#     'pressure': 1015.38,
#     'windSpeed': 4.22,
#     'windGust': 7.28,
#     'windBearing': 144,
#     'cloudCover': 0.75,
#     'uvIndex': 2,
#     'visibility': 8.05,
#     'ozone': 298.52},
#    {'time': 1560207600,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0331,
#     'precipProbability': 0.93,
#     'precipType': 'rain',
#     'temperature': 86.99,
#     'apparentTemperature': 98.82,
#     'dewPoint': 77.06,
#     'humidity': 0.73,
#     'pressure': 1015.24,
#     'windSpeed': 3.65,
#     'windGust': 6.69,
#     'windBearing': 142,
#     'cloudCover': 0.73,
#     'uvIndex': 0,
#     'visibility': 9.52,
#     'ozone': 299.06},
#    {'time': 1560211200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0116,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'temperature': 85.04,
#     'apparentTemperature': 94.71,
#     'dewPoint': 76.14,
#     'humidity': 0.75,
#     'pressure': 1015.3,
#     'windSpeed': 3.62,
#     'windGust': 6.28,
#     'windBearing': 97,
#     'cloudCover': 0.7,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.39},
#    {'time': 1560214800,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0028,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 83.33,
#     'apparentTemperature': 91.26,
#     'dewPoint': 75.43,
#     'humidity': 0.77,
#     'pressure': 1015.58,
#     'windSpeed': 5.01,
#     'windGust': 6.74,
#     'windBearing': 87,
#     'cloudCover': 0.6,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.26},
#    {'time': 1560218400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0019,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 82.42,
#     'apparentTemperature': 89.65,
#     'dewPoint': 75.37,
#     'humidity': 0.79,
#     'pressure': 1016.03,
#     'windSpeed': 5.75,
#     'windGust': 7.48,
#     'windBearing': 92,
#     'cloudCover': 0.47,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299},
#    {'time': 1560222000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0021,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 81.36,
#     'apparentTemperature': 87.59,
#     'dewPoint': 75.16,
#     'humidity': 0.82,
#     'pressure': 1016.34,
#     'windSpeed': 6.07,
#     'windGust': 7.78,
#     'windBearing': 98,
#     'cloudCover': 0.38,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.17},
#    {'time': 1560225600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 80.56,
#     'apparentTemperature': 85.94,
#     'dewPoint': 74.87,
#     'humidity': 0.83,
#     'pressure': 1016.44,
#     'windSpeed': 5.9,
#     'windGust': 7.52,
#     'windBearing': 106,
#     'cloudCover': 0.36,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 300.37},
#    {'time': 1560229200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 79.97,
#     'apparentTemperature': 84.65,
#     'dewPoint': 74.52,
#     'humidity': 0.84,
#     'pressure': 1016.45,
#     'windSpeed': 5.58,
#     'windGust': 7.01,
#     'windBearing': 115,
#     'cloudCover': 0.35,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.04},
#    {'time': 1560232800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.52,
#     'apparentTemperature': 83.65,
#     'dewPoint': 74.2,
#     'humidity': 0.84,
#     'pressure': 1016.34,
#     'windSpeed': 5.3,
#     'windGust': 6.6,
#     'windBearing': 121,
#     'cloudCover': 0.26,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.21},
#    {'time': 1560236400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79,
#     'apparentTemperature': 82.53,
#     'dewPoint': 73.91,
#     'humidity': 0.84,
#     'pressure': 1016.05,
#     'windSpeed': 5.19,
#     'windGust': 6.44,
#     'windBearing': 125,
#     'cloudCover': 0.21,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.46},
#    {'time': 1560240000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0013,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 78.28,
#     'apparentTemperature': 79.84,
#     'dewPoint': 73.66,
#     'humidity': 0.86,
#     'pressure': 1015.65,
#     'windSpeed': 5.13,
#     'windGust': 6.32,
#     'windBearing': 128,
#     'cloudCover': 0.19,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.28},
#    {'time': 1560243600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 78.23,
#     'apparentTemperature': 79.78,
#     'dewPoint': 73.54,
#     'humidity': 0.86,
#     'pressure': 1015.49,
#     'windSpeed': 5.04,
#     'windGust': 5.98,
#     'windBearing': 130,
#     'cloudCover': 0.1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.89},
#    {'time': 1560247200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 78.58,
#     'apparentTemperature': 81.64,
#     'dewPoint': 73.66,
#     'humidity': 0.85,
#     'pressure': 1015.66,
#     'windSpeed': 5.07,
#     'windGust': 5.52,
#     'windBearing': 134,
#     'cloudCover': 0.11,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.4},
#    {'time': 1560250800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 79.21,
#     'apparentTemperature': 82.96,
#     'dewPoint': 73.9,
#     'humidity': 0.84,
#     'pressure': 1015.99,
#     'windSpeed': 5.16,
#     'windGust': 5.27,
#     'windBearing': 139,
#     'cloudCover': 0.14,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 301.82},
#    {'time': 1560254400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 80.22,
#     'apparentTemperature': 84.84,
#     'dewPoint': 73.83,
#     'humidity': 0.81,
#     'pressure': 1016.18,
#     'windSpeed': 5.12,
#     'windGust': 5.15,
#     'windBearing': 137,
#     'cloudCover': 0.11,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 301.25},
#    {'time': 1560258000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 82.78,
#     'apparentTemperature': 88.94,
#     'dewPoint': 73.53,
#     'humidity': 0.74,
#     'pressure': 1016.48,
#     'windSpeed': 4.78,
#     'windGust': 4.8,
#     'windBearing': 134,
#     'cloudCover': 0.11,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 300.96},
#    {'time': 1560261600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 86.01,
#     'apparentTemperature': 93.17,
#     'dewPoint': 73.03,
#     'humidity': 0.65,
#     'pressure': 1016.79,
#     'windSpeed': 4.29,
#     'windGust': 4.35,
#     'windBearing': 129,
#     'cloudCover': 0.1,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 300.66},
#    {'time': 1560265200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 88.42,
#     'apparentTemperature': 95.98,
#     'dewPoint': 72.65,
#     'humidity': 0.6,
#     'pressure': 1016.88,
#     'windSpeed': 4.12,
#     'windGust': 4.39,
#     'windBearing': 118,
#     'cloudCover': 0.11,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 300.34},
#    {'time': 1560268800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0007,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 89.91,
#     'apparentTemperature': 97.76,
#     'dewPoint': 72.53,
#     'humidity': 0.57,
#     'pressure': 1016.72,
#     'windSpeed': 4.52,
#     'windGust': 4.79,
#     'windBearing': 96,
#     'cloudCover': 0.12,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 299.93},
#    {'time': 1560272400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.003,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 90.57,
#     'apparentTemperature': 98.63,
#     'dewPoint': 72.56,
#     'humidity': 0.56,
#     'pressure': 1016.37,
#     'windSpeed': 5.22,
#     'windGust': 5.43,
#     'windBearing': 67,
#     'cloudCover': 0.15,
#     'uvIndex': 10,
#     'visibility': 10,
#     'ozone': 299.5},
#    {'time': 1560276000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0065,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 90.91,
#     'apparentTemperature': 99.25,
#     'dewPoint': 72.74,
#     'humidity': 0.56,
#     'pressure': 1015.97,
#     'windSpeed': 5.94,
#     'windGust': 6.14,
#     'windBearing': 45,
#     'cloudCover': 0.19,
#     'uvIndex': 10,
#     'visibility': 10,
#     'ozone': 299.3},
#    {'time': 1560279600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0124,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 91,
#     'apparentTemperature': 99.71,
#     'dewPoint': 73.06,
#     'humidity': 0.56,
#     'pressure': 1015.53,
#     'windSpeed': 6.71,
#     'windGust': 6.93,
#     'windBearing': 38,
#     'cloudCover': 0.24,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 299.58},
#    {'time': 1560283200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0244,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 90,
#     'apparentTemperature': 98.9,
#     'dewPoint': 73.51,
#     'humidity': 0.59,
#     'pressure': 1015.02,
#     'windSpeed': 7.49,
#     'windGust': 8.18,
#     'windBearing': 38,
#     'cloudCover': 0.3,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 300.14},
#    {'time': 1560286800,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0335,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 88.65,
#     'apparentTemperature': 97.56,
#     'dewPoint': 73.91,
#     'humidity': 0.62,
#     'pressure': 1014.68,
#     'windSpeed': 7.98,
#     'windGust': 9.3,
#     'windBearing': 41,
#     'cloudCover': 0.35,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 300.69},
#    {'time': 1560290400,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0302,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 87.35,
#     'apparentTemperature': 96.06,
#     'dewPoint': 74.15,
#     'humidity': 0.65,
#     'pressure': 1014.57,
#     'windSpeed': 7.9,
#     'windGust': 9.96,
#     'windBearing': 45,
#     'cloudCover': 0.45,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 301.02},
#    {'time': 1560294000,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0308,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 85.83,
#     'apparentTemperature': 94.08,
#     'dewPoint': 74.3,
#     'humidity': 0.69,
#     'pressure': 1014.62,
#     'windSpeed': 7.5,
#     'windGust': 10.38,
#     'windBearing': 52,
#     'cloudCover': 0.55,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 301.22},
#    {'time': 1560297600,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.035,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 84.33,
#     'apparentTemperature': 91.93,
#     'dewPoint': 74.34,
#     'humidity': 0.72,
#     'pressure': 1014.85,
#     'windSpeed': 7.21,
#     'windGust': 10.85,
#     'windBearing': 61,
#     'cloudCover': 0.61,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 301.54},
#    {'time': 1560301200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0263,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 82.96,
#     'apparentTemperature': 89.78,
#     'dewPoint': 74.31,
#     'humidity': 0.75,
#     'pressure': 1015.41,
#     'windSpeed': 7.38,
#     'windGust': 11.78,
#     'windBearing': 73,
#     'cloudCover': 0.55,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 301.99},
#    {'time': 1560304800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0146,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 82.06,
#     'apparentTemperature': 88.24,
#     'dewPoint': 74.2,
#     'humidity': 0.77,
#     'pressure': 1016.14,
#     'windSpeed': 7.65,
#     'windGust': 12.7,
#     'windBearing': 87,
#     'cloudCover': 0.43,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.34},
#    {'time': 1560308400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.009,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 81.14,
#     'apparentTemperature': 86.62,
#     'dewPoint': 74.1,
#     'humidity': 0.79,
#     'pressure': 1016.61,
#     'windSpeed': 7.59,
#     'windGust': 12.69,
#     'windBearing': 100,
#     'cloudCover': 0.35,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.69},
#    {'time': 1560312000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0048,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 80.42,
#     'apparentTemperature': 85.3,
#     'dewPoint': 74.03,
#     'humidity': 0.81,
#     'pressure': 1016.56,
#     'windSpeed': 7.08,
#     'windGust': 10.97,
#     'windBearing': 109,
#     'cloudCover': 0.38,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.13},
#    {'time': 1560315600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 79.86,
#     'apparentTemperature': 84.22,
#     'dewPoint': 73.94,
#     'humidity': 0.82,
#     'pressure': 1016.26,
#     'windSpeed': 6.32,
#     'windGust': 8.34,
#     'windBearing': 116,
#     'cloudCover': 0.45,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.49},
#    {'time': 1560319200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 79.39,
#     'apparentTemperature': 83.28,
#     'dewPoint': 73.83,
#     'humidity': 0.83,
#     'pressure': 1015.94,
#     'windSpeed': 5.59,
#     'windGust': 6.27,
#     'windBearing': 122,
#     'cloudCover': 0.47,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.44},
#    {'time': 1560322800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.76,
#     'apparentTemperature': 82,
#     'dewPoint': 73.61,
#     'humidity': 0.84,
#     'pressure': 1015.62,
#     'windSpeed': 4.96,
#     'windGust': 5.38,
#     'windBearing': 127,
#     'cloudCover': 0.39,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.66},
#    {'time': 1560326400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.89,
#     'apparentTemperature': 79.43,
#     'dewPoint': 73.36,
#     'humidity': 0.86,
#     'pressure': 1015.29,
#     'windSpeed': 4.34,
#     'windGust': 4.98,
#     'windBearing': 130,
#     'cloudCover': 0.26,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 301.45},
#    {'time': 1560330000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.8,
#     'apparentTemperature': 79.31,
#     'dewPoint': 73.2,
#     'humidity': 0.86,
#     'pressure': 1015.16,
#     'windSpeed': 3.97,
#     'windGust': 4.83,
#     'windBearing': 133,
#     'cloudCover': 0.15,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 300.46},
#    {'time': 1560333600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.27,
#     'apparentTemperature': 79.77,
#     'dewPoint': 73.22,
#     'humidity': 0.85,
#     'pressure': 1015.31,
#     'windSpeed': 3.98,
#     'windGust': 4.93,
#     'windBearing': 135,
#     'cloudCover': 0.11,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 300.02},
#    {'time': 1560337200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.18,
#     'apparentTemperature': 82.74,
#     'dewPoint': 73.32,
#     'humidity': 0.82,
#     'pressure': 1015.64,
#     'windSpeed': 4.22,
#     'windGust': 5.36,
#     'windBearing': 136,
#     'cloudCover': 0.09,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 299.8},
#    {'time': 1560340800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.63,
#     'apparentTemperature': 85.39,
#     'dewPoint': 73.41,
#     'humidity': 0.79,
#     'pressure': 1015.98,
#     'windSpeed': 4.46,
#     'windGust': 5.81,
#     'windBearing': 137,
#     'cloudCover': 0.08,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 299.57},
#    {'time': 1560344400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 83.12,
#     'apparentTemperature': 89.42,
#     'dewPoint': 73.47,
#     'humidity': 0.73,
#     'pressure': 1016.32,
#     'windSpeed': 4.61,
#     'windGust': 6.24,
#     'windBearing': 141,
#     'cloudCover': 0.06,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 299.32},
#    {'time': 1560348000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 86.09,
#     'apparentTemperature': 93.75,
#     'dewPoint': 73.55,
#     'humidity': 0.66,
#     'pressure': 1016.66,
#     'windSpeed': 4.77,
#     'windGust': 6.75,
#     'windBearing': 146,
#     'cloudCover': 0.03,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 299.07},
#    {'time': 1560351600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0006,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 88.46,
#     'apparentTemperature': 96.93,
#     'dewPoint': 73.55,
#     'humidity': 0.62,
#     'pressure': 1016.85,
#     'windSpeed': 4.82,
#     'windGust': 7.04,
#     'windBearing': 147,
#     'cloudCover': 0.02,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 298.87},
#    {'time': 1560355200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0073,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 89.65,
#     'apparentTemperature': 98.28,
#     'dewPoint': 73.35,
#     'humidity': 0.59,
#     'pressure': 1016.84,
#     'windSpeed': 4.18,
#     'windGust': 6.76,
#     'windBearing': 141,
#     'cloudCover': 0.04,
#     'uvIndex': 10,
#     'visibility': 10,
#     'ozone': 298.88},
#    {'time': 1560358800,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0319,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 90.46,
#     'apparentTemperature': 99,
#     'dewPoint': 73.05,
#     'humidity': 0.57,
#     'pressure': 1016.65,
#     'windSpeed': 2.86,
#     'windGust': 6.31,
#     'windBearing': 144,
#     'cloudCover': 0.08,
#     'uvIndex': 11,
#     'visibility': 10,
#     'ozone': 298.89},
#    {'time': 1560362400,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0554,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 90.88,
#     'apparentTemperature': 99.33,
#     'dewPoint': 72.85,
#     'humidity': 0.56,
#     'pressure': 1016.39,
#     'windSpeed': 2.09,
#     'windGust': 6.06,
#     'windBearing': 156,
#     'cloudCover': 0.11,
#     'uvIndex': 11,
#     'visibility': 10,
#     'ozone': 298.3},
#    {'time': 1560366000,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0504,
#     'precipProbability': 0.16,
#     'precipType': 'rain',
#     'temperature': 91.14,
#     'apparentTemperature': 99.72,
#     'dewPoint': 72.9,
#     'humidity': 0.55,
#     'pressure': 1015.99,
#     'windSpeed': 2.14,
#     'windGust': 6.2,
#     'windBearing': 140,
#     'cloudCover': 0.16,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 296.43},
#    {'time': 1560369600,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0355,
#     'precipProbability': 0.17,
#     'precipType': 'rain',
#     'temperature': 90.29,
#     'apparentTemperature': 98.83,
#     'dewPoint': 73.1,
#     'humidity': 0.57,
#     'pressure': 1015.49,
#     'windSpeed': 2.71,
#     'windGust': 6.53,
#     'windBearing': 126,
#     'cloudCover': 0.21,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 293.91},
#    {'time': 1560373200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0256,
#     'precipProbability': 0.18,
#     'precipType': 'rain',
#     'temperature': 89.01,
#     'apparentTemperature': 97.42,
#     'dewPoint': 73.32,
#     'humidity': 0.6,
#     'pressure': 1015.19,
#     'windSpeed': 2.58,
#     'windGust': 6.86,
#     'windBearing': 133,
#     'cloudCover': 0.24,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 291.8},
#    {'time': 1560376800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0159,
#     'precipProbability': 0.15,
#     'precipType': 'rain',
#     'temperature': 87.61,
#     'apparentTemperature': 95.82,
#     'dewPoint': 73.57,
#     'humidity': 0.63,
#     'pressure': 1015.18,
#     'windSpeed': 3.5,
#     'windGust': 7.14,
#     'windBearing': 128,
#     'cloudCover': 0.22,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 290.62}]},
#  'daily': {'summary': 'Light rain today through Sunday, with high temperatures peaking at 91°F on Thursday.',
#   'icon': 'rain',
#   'data': [{'time': 1560139200,
#     'summary': 'Light rain starting in the afternoon, continuing until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560163474,
#     'sunsetTime': 1560212171,
#     'moonPhase': 0.27,
#     'precipIntensity': 0.0109,
#     'precipIntensityMax': 0.0459,
#     'precipIntensityMaxTime': 1560189600,
#     'precipProbability': 0.93,
#     'precipType': 'rain',
#     'temperatureHigh': 89.24,
#     'temperatureHighTime': 1560200400,
#     'temperatureLow': 78.23,
#     'temperatureLowTime': 1560243600,
#     'apparentTemperatureHigh': 101.69,
#     'apparentTemperatureHighTime': 1560200400,
#     'apparentTemperatureLow': 79.78,
#     'apparentTemperatureLowTime': 1560243600,
#     'dewPoint': 75.85,
#     'humidity': 0.79,
#     'pressure': 1015.87,
#     'windSpeed': 4.17,
#     'windGust': 12.72,
#     'windGustTime': 1560146400,
#     'windBearing': 120,
#     'cloudCover': 0.47,
#     'uvIndex': 6,
#     'uvIndexTime': 1560182400,
#     'visibility': 6.41,
#     'ozone': 299.84,
#     'temperatureMin': 76.63,
#     'temperatureMinTime': 1560160800,
#     'temperatureMax': 89.24,
#     'temperatureMaxTime': 1560200400,
#     'apparentTemperatureMin': 78.54,
#     'apparentTemperatureMinTime': 1560160800,
#     'apparentTemperatureMax': 101.69,
#     'apparentTemperatureMaxTime': 1560200400},
#    {'time': 1560225600,
#     'summary': 'Light rain in the evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560249877,
#     'sunsetTime': 1560298591,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0097,
#     'precipIntensityMax': 0.035,
#     'precipIntensityMaxTime': 1560297600,
#     'precipProbability': 0.44,
#     'precipType': 'rain',
#     'temperatureHigh': 91,
#     'temperatureHighTime': 1560279600,
#     'temperatureLow': 77.8,
#     'temperatureLowTime': 1560330000,
#     'apparentTemperatureHigh': 99.71,
#     'apparentTemperatureHighTime': 1560279600,
#     'apparentTemperatureLow': 79.31,
#     'apparentTemperatureLowTime': 1560330000,
#     'dewPoint': 73.71,
#     'humidity': 0.72,
#     'pressure': 1015.87,
#     'windSpeed': 4.82,
#     'windGust': 12.7,
#     'windGustTime': 1560304800,
#     'windBearing': 89,
#     'cloudCover': 0.27,
#     'uvIndex': 10,
#     'uvIndexTime': 1560272400,
#     'visibility': 10,
#     'ozone': 301.36,
#     'temperatureMin': 78.23,
#     'temperatureMinTime': 1560243600,
#     'temperatureMax': 91,
#     'temperatureMaxTime': 1560279600,
#     'apparentTemperatureMin': 79.78,
#     'apparentTemperatureMinTime': 1560243600,
#     'apparentTemperatureMax': 99.71,
#     'apparentTemperatureMaxTime': 1560279600},
#    {'time': 1560312000,
#     'summary': 'Rain in the afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560336280,
#     'sunsetTime': 1560385011,
#     'moonPhase': 0.34,
#     'precipIntensity': 0.0113,
#     'precipIntensityMax': 0.0554,
#     'precipIntensityMaxTime': 1560362400,
#     'precipProbability': 0.53,
#     'precipType': 'rain',
#     'temperatureHigh': 91.14,
#     'temperatureHighTime': 1560366000,
#     'temperatureLow': 77.96,
#     'temperatureLowTime': 1560416400,
#     'apparentTemperatureHigh': 99.72,
#     'apparentTemperatureHighTime': 1560366000,
#     'apparentTemperatureLow': 79.64,
#     'apparentTemperatureLowTime': 1560416400,
#     'dewPoint': 73.57,
#     'humidity': 0.72,
#     'pressure': 1016.05,
#     'windSpeed': 4.37,
#     'windGust': 10.97,
#     'windGustTime': 1560312000,
#     'windBearing': 130,
#     'cloudCover': 0.19,
#     'uvIndex': 11,
#     'uvIndexTime': 1560358800,
#     'visibility': 10,
#     'ozone': 296.72,
#     'temperatureMin': 77.8,
#     'temperatureMinTime': 1560330000,
#     'temperatureMax': 91.14,
#     'temperatureMaxTime': 1560366000,
#     'apparentTemperatureMin': 79.31,
#     'apparentTemperatureMinTime': 1560330000,
#     'apparentTemperatureMax': 99.72,
#     'apparentTemperatureMaxTime': 1560366000},
#    {'time': 1560398400,
#     'summary': 'Humid and partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560422685,
#     'sunsetTime': 1560471430,
#     'moonPhase': 0.38,
#     'precipIntensity': 0.0046,
#     'precipIntensityMax': 0.0293,
#     'precipIntensityMaxTime': 1560448800,
#     'precipProbability': 0.32,
#     'precipType': 'rain',
#     'temperatureHigh': 91.34,
#     'temperatureHighTime': 1560452400,
#     'temperatureLow': 78.7,
#     'temperatureLowTime': 1560502800,
#     'apparentTemperatureHigh': 98.75,
#     'apparentTemperatureHighTime': 1560456000,
#     'apparentTemperatureLow': 81.72,
#     'apparentTemperatureLowTime': 1560502800,
#     'dewPoint': 73.76,
#     'humidity': 0.73,
#     'pressure': 1017.43,
#     'windSpeed': 4.04,
#     'windGust': 12.81,
#     'windGustTime': 1560481200,
#     'windBearing': 110,
#     'cloudCover': 0.3,
#     'uvIndex': 10,
#     'uvIndexTime': 1560441600,
#     'visibility': 10,
#     'ozone': 281.25,
#     'temperatureMin': 77.96,
#     'temperatureMinTime': 1560416400,
#     'temperatureMax': 91.34,
#     'temperatureMaxTime': 1560452400,
#     'apparentTemperatureMin': 79.64,
#     'apparentTemperatureMinTime': 1560416400,
#     'apparentTemperatureMax': 98.75,
#     'apparentTemperatureMaxTime': 1560456000},
#    {'time': 1560484800,
#     'summary': 'Light rain starting in the evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560509090,
#     'sunsetTime': 1560557849,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0068,
#     'precipIntensityMax': 0.0362,
#     'precipIntensityMaxTime': 1560560400,
#     'precipProbability': 0.49,
#     'precipType': 'rain',
#     'temperatureHigh': 90.93,
#     'temperatureHighTime': 1560542400,
#     'temperatureLow': 79.32,
#     'temperatureLowTime': 1560585600,
#     'apparentTemperatureHigh': 100.22,
#     'apparentTemperatureHighTime': 1560542400,
#     'apparentTemperatureLow': 83.16,
#     'apparentTemperatureLowTime': 1560585600,
#     'dewPoint': 73.72,
#     'humidity': 0.71,
#     'pressure': 1016.9,
#     'windSpeed': 8.58,
#     'windGust': 19.93,
#     'windGustTime': 1560567600,
#     'windBearing': 71,
#     'cloudCover': 0.63,
#     'uvIndex': 9,
#     'uvIndexTime': 1560531600,
#     'visibility': 9.31,
#     'ozone': 277.43,
#     'temperatureMin': 78.7,
#     'temperatureMinTime': 1560502800,
#     'temperatureMax': 90.93,
#     'temperatureMaxTime': 1560542400,
#     'apparentTemperatureMin': 81.72,
#     'apparentTemperatureMinTime': 1560502800,
#     'apparentTemperatureMax': 100.22,
#     'apparentTemperatureMaxTime': 1560542400},
#    {'time': 1560571200,
#     'summary': 'Humid and overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1560595497,
#     'sunsetTime': 1560644266,
#     'moonPhase': 0.45,
#     'precipIntensity': 0.0112,
#     'precipIntensityMax': 0.0371,
#     'precipIntensityMaxTime': 1560643200,
#     'precipProbability': 0.72,
#     'precipType': 'rain',
#     'temperatureHigh': 89.19,
#     'temperatureHighTime': 1560621600,
#     'temperatureLow': 77.97,
#     'temperatureLowTime': 1560675600,
#     'apparentTemperatureHigh': 98.26,
#     'apparentTemperatureHighTime': 1560628800,
#     'apparentTemperatureLow': 79.52,
#     'apparentTemperatureLowTime': 1560675600,
#     'dewPoint': 73.97,
#     'humidity': 0.74,
#     'pressure': 1016.11,
#     'windSpeed': 10.19,
#     'windGust': 20.01,
#     'windGustTime': 1560571200,
#     'windBearing': 90,
#     'cloudCover': 0.98,
#     'uvIndex': 6,
#     'uvIndexTime': 1560618000,
#     'visibility': 9.06,
#     'ozone': 277.4,
#     'temperatureMin': 79.32,
#     'temperatureMinTime': 1560585600,
#     'temperatureMax': 89.19,
#     'temperatureMaxTime': 1560621600,
#     'apparentTemperatureMin': 83.16,
#     'apparentTemperatureMinTime': 1560585600,
#     'apparentTemperatureMax': 98.26,
#     'apparentTemperatureMaxTime': 1560628800},
#    {'time': 1560657600,
#     'summary': 'Rain starting in the afternoon, continuing until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560681904,
#     'sunsetTime': 1560730683,
#     'moonPhase': 0.48,
#     'precipIntensity': 0.0185,
#     'precipIntensityMax': 0.0644,
#     'precipIntensityMaxTime': 1560718800,
#     'precipProbability': 0.82,
#     'precipType': 'rain',
#     'temperatureHigh': 89.27,
#     'temperatureHighTime': 1560715200,
#     'temperatureLow': 77.84,
#     'temperatureLowTime': 1560758400,
#     'apparentTemperatureHigh': 98.87,
#     'apparentTemperatureHighTime': 1560715200,
#     'apparentTemperatureLow': 79.26,
#     'apparentTemperatureLowTime': 1560758400,
#     'dewPoint': 73.99,
#     'humidity': 0.75,
#     'pressure': 1015.68,
#     'windSpeed': 7.61,
#     'windGust': 15.39,
#     'windGustTime': 1560675600,
#     'windBearing': 112,
#     'cloudCover': 0.89,
#     'uvIndex': 5,
#     'uvIndexTime': 1560697200,
#     'visibility': 8.75,
#     'ozone': 282.8,
#     'temperatureMin': 77.97,
#     'temperatureMinTime': 1560675600,
#     'temperatureMax': 89.27,
#     'temperatureMaxTime': 1560715200,
#     'apparentTemperatureMin': 79.52,
#     'apparentTemperatureMinTime': 1560675600,
#     'apparentTemperatureMax': 98.87,
#     'apparentTemperatureMaxTime': 1560715200},
#    {'time': 1560744000,
#     'summary': 'Humid throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1560768312,
#     'sunsetTime': 1560817099,
#     'moonPhase': 0.52,
#     'precipIntensity': 0.0015,
#     'precipIntensityMax': 0.0072,
#     'precipIntensityMaxTime': 1560794400,
#     'precipProbability': 0.28,
#     'precipType': 'rain',
#     'temperatureHigh': 90.51,
#     'temperatureHighTime': 1560801600,
#     'temperatureLow': 78.65,
#     'temperatureLowTime': 1560844800,
#     'apparentTemperatureHigh': 98.37,
#     'apparentTemperatureHighTime': 1560805200,
#     'apparentTemperatureLow': 81.57,
#     'apparentTemperatureLowTime': 1560844800,
#     'dewPoint': 73.34,
#     'humidity': 0.73,
#     'pressure': 1016.17,
#     'windSpeed': 4.47,
#     'windGust': 11.15,
#     'windGustTime': 1560744000,
#     'windBearing': 120,
#     'cloudCover': 0.06,
#     'uvIndex': 12,
#     'uvIndexTime': 1560790800,
#     'visibility': 10,
#     'ozone': 285.62,
#     'temperatureMin': 77.84,
#     'temperatureMinTime': 1560758400,
#     'temperatureMax': 90.51,
#     'temperatureMaxTime': 1560801600,
#     'apparentTemperatureMin': 79.26,
#     'apparentTemperatureMinTime': 1560758400,
#     'apparentTemperatureMax': 98.37,
#     'apparentTemperatureMaxTime': 1560805200}]},
#  'flags': {'sources': ['nearest-precip',
#    'cmc',
#    'gfs',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 3.838,
#   'units': 'us'},
#  'offset': -4}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*
