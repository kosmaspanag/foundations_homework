# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
# !pip install python_dotenv
# Out:
# Requirement already satisfied: python_dotenv in /Users/kosmas/.pyenv/versions/3.7.1/lib/python3.7/site-packages (0.10.3)
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !touch .env

# %%
echo %PATH%
# Out:
#   File "<ipython-input-6-b8194f16ad87>", line 1
#     echo %PATH%
#                ^
# SyntaxError: invalid syntax

# %%
from dotenv import load_dotenv
#load_dotenv('/Users/kosmas/Downloads/.env')
load_dotenv('.env')

import os
API_KEY = os.getenv("DARKSKY_API_KEY")
API_KEY
# Out:
# '9876b3ab257379b93910aa171d94a5d1'

# %%
import requests

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/23.113592, -82.366592')
cuba = response.json()

# %%
cuba
# Out:
# {'latitude': 23.113592,
#  'longitude': -82.366592,
#  'timezone': 'America/Havana',
#  'currently': {'time': 1560278678,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'nearestStormDistance': 4,
#   'nearestStormBearing': 106,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 91.26,
#   'apparentTemperature': 102,
#   'dewPoint': 74.76,
#   'humidity': 0.59,
#   'pressure': 1015.77,
#   'windSpeed': 8.68,
#   'windGust': 8.68,
#   'windBearing': 34,
#   'cloudCover': 0.82,
#   'uvIndex': 6,
#   'visibility': 6.79,
#   'ozone': 298.65},
#  'minutely': {'summary': 'Humid and mostly cloudy for the hour.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560278640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560278700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560278760,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560278820,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560278880,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560278940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279840,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560279900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560279960,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.004,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560280020,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.007,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1560280080,
#     'precipIntensity': 0.007,
#     'precipIntensityError': 0.014,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1560280140,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.012,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560280200,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.014,
#     'precipProbability': 0.05,
#     'precipType': 'rain'},
#    {'time': 1560280260,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.015,
#     'precipProbability': 0.06,
#     'precipType': 'rain'},
#    {'time': 1560280320,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.022,
#     'precipProbability': 0.07,
#     'precipType': 'rain'},
#    {'time': 1560280380,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.021,
#     'precipProbability': 0.07,
#     'precipType': 'rain'},
#    {'time': 1560280440,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.023,
#     'precipProbability': 0.08,
#     'precipType': 'rain'},
#    {'time': 1560280500,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.026,
#     'precipProbability': 0.08,
#     'precipType': 'rain'},
#    {'time': 1560280560,
#     'precipIntensity': 0.012,
#     'precipIntensityError': 0.027,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560280620,
#     'precipIntensity': 0.013,
#     'precipIntensityError': 0.03,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560280680,
#     'precipIntensity': 0.013,
#     'precipIntensityError': 0.035,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560280740,
#     'precipIntensity': 0.012,
#     'precipIntensityError': 0.022,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560280800,
#     'precipIntensity': 0.014,
#     'precipIntensityError': 0.033,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560280860,
#     'precipIntensity': 0.013,
#     'precipIntensityError': 0.034,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560280920,
#     'precipIntensity': 0.012,
#     'precipIntensityError': 0.026,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560280980,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.03,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560281040,
#     'precipIntensity': 0.013,
#     'precipIntensityError': 0.038,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560281100,
#     'precipIntensity': 0.013,
#     'precipIntensityError': 0.035,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1560281160,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.028,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1560281220,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.03,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1560281280,
#     'precipIntensity': 0.013,
#     'precipIntensityError': 0.035,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1560281340,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.03,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1560281400,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.029,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1560281460,
#     'precipIntensity': 0.01,
#     'precipIntensityError': 0.031,
#     'precipProbability': 0.11,
#     'precipType': 'rain'},
#    {'time': 1560281520,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.033,
#     'precipProbability': 0.11,
#     'precipType': 'rain'},
#    {'time': 1560281580,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.03,
#     'precipProbability': 0.11,
#     'precipType': 'rain'},
#    {'time': 1560281640,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.023,
#     'precipProbability': 0.12,
#     'precipType': 'rain'},
#    {'time': 1560281700,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.024,
#     'precipProbability': 0.12,
#     'precipType': 'rain'},
#    {'time': 1560281760,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.033,
#     'precipProbability': 0.13,
#     'precipType': 'rain'},
#    {'time': 1560281820,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.024,
#     'precipProbability': 0.14,
#     'precipType': 'rain'},
#    {'time': 1560281880,
#     'precipIntensity': 0.007,
#     'precipIntensityError': 0.017,
#     'precipProbability': 0.14,
#     'precipType': 'rain'},
#    {'time': 1560281940,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.022,
#     'precipProbability': 0.15,
#     'precipType': 'rain'},
#    {'time': 1560282000,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.024,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1560282060,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.035,
#     'precipProbability': 0.17,
#     'precipType': 'rain'},
#    {'time': 1560282120,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.026,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1560282180,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.026,
#     'precipProbability': 0.19,
#     'precipType': 'rain'},
#    {'time': 1560282240,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.025,
#     'precipProbability': 0.2,
#     'precipType': 'rain'}]},
#  'hourly': {'summary': 'Rain this evening.',
#   'icon': 'rain',
#   'data': [{'time': 1560276000,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0185,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 91.15,
#     'apparentTemperature': 101.61,
#     'dewPoint': 74.56,
#     'humidity': 0.59,
#     'pressure': 1016.09,
#     'windSpeed': 8.17,
#     'windGust': 8.17,
#     'windBearing': 36,
#     'cloudCover': 0.75,
#     'uvIndex': 6,
#     'visibility': 7.6,
#     'ozone': 298.74},
#    {'time': 1560279600,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0091,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 91.3,
#     'apparentTemperature': 102.13,
#     'dewPoint': 74.83,
#     'humidity': 0.59,
#     'pressure': 1015.66,
#     'windSpeed': 8.85,
#     'windGust': 8.85,
#     'windBearing': 33,
#     'cloudCover': 0.84,
#     'uvIndex': 5,
#     'visibility': 6.51,
#     'ozone': 298.61},
#    {'time': 1560283200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0195,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'temperature': 90.36,
#     'apparentTemperature': 101.03,
#     'dewPoint': 74.95,
#     'humidity': 0.61,
#     'pressure': 1015.24,
#     'windSpeed': 8.61,
#     'windGust': 8.61,
#     'windBearing': 34,
#     'cloudCover': 0.91,
#     'uvIndex': 4,
#     'visibility': 5.92,
#     'ozone': 298.64},
#    {'time': 1560286800,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0247,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 88.79,
#     'apparentTemperature': 98.16,
#     'dewPoint': 74.3,
#     'humidity': 0.63,
#     'pressure': 1014.92,
#     'windSpeed': 7.05,
#     'windGust': 7.54,
#     'windBearing': 46,
#     'cloudCover': 0.78,
#     'uvIndex': 3,
#     'visibility': 8.25,
#     'ozone': 298.68},
#    {'time': 1560290400,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0284,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 87.32,
#     'apparentTemperature': 95.83,
#     'dewPoint': 73.97,
#     'humidity': 0.65,
#     'pressure': 1014.78,
#     'windSpeed': 6.25,
#     'windGust': 7.76,
#     'windBearing': 58,
#     'cloudCover': 0.64,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 298.72},
#    {'time': 1560294000,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0529,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 85.85,
#     'apparentTemperature': 94.11,
#     'dewPoint': 74.3,
#     'humidity': 0.69,
#     'pressure': 1014.83,
#     'windSpeed': 6.17,
#     'windGust': 8,
#     'windBearing': 64,
#     'cloudCover': 0.59,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.76},
#    {'time': 1560297600,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0719,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 84.46,
#     'apparentTemperature': 92.29,
#     'dewPoint': 74.53,
#     'humidity': 0.72,
#     'pressure': 1015,
#     'windSpeed': 6.24,
#     'windGust': 8.28,
#     'windBearing': 70,
#     'cloudCover': 0.52,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.83},
#    {'time': 1560301200,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0423,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 83.34,
#     'apparentTemperature': 90.58,
#     'dewPoint': 74.57,
#     'humidity': 0.75,
#     'pressure': 1015.38,
#     'windSpeed': 6.54,
#     'windGust': 8.59,
#     'windBearing': 81,
#     'cloudCover': 0.44,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.85},
#    {'time': 1560304800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.008,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 82.62,
#     'apparentTemperature': 89.35,
#     'dewPoint': 74.48,
#     'humidity': 0.77,
#     'pressure': 1015.85,
#     'windSpeed': 6.73,
#     'windGust': 8.48,
#     'windBearing': 93,
#     'cloudCover': 0.32,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.77},
#    {'time': 1560308400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.69,
#     'apparentTemperature': 87.76,
#     'dewPoint': 74.42,
#     'humidity': 0.79,
#     'pressure': 1016.16,
#     'windSpeed': 6.74,
#     'windGust': 8.26,
#     'windBearing': 105,
#     'cloudCover': 0.21,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.65},
#    {'time': 1560312000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.96,
#     'apparentTemperature': 86.49,
#     'dewPoint': 74.48,
#     'humidity': 0.81,
#     'pressure': 1016.15,
#     'windSpeed': 6.4,
#     'windGust': 7.84,
#     'windBearing': 116,
#     'cloudCover': 0.17,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.55},
#    {'time': 1560315600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.35,
#     'apparentTemperature': 85.38,
#     'dewPoint': 74.53,
#     'humidity': 0.83,
#     'pressure': 1015.95,
#     'windSpeed': 5.81,
#     'windGust': 7.08,
#     'windBearing': 126,
#     'cloudCover': 0.14,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.44},
#    {'time': 1560319200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 79.85,
#     'apparentTemperature': 84.41,
#     'dewPoint': 74.54,
#     'humidity': 0.84,
#     'pressure': 1015.77,
#     'windSpeed': 5.25,
#     'windGust': 6.41,
#     'windBearing': 134,
#     'cloudCover': 0.13,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.25},
#    {'time': 1560322800,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.33,
#     'apparentTemperature': 83.33,
#     'dewPoint': 74.4,
#     'humidity': 0.85,
#     'pressure': 1015.61,
#     'windSpeed': 4.83,
#     'windGust': 5.97,
#     'windBearing': 141,
#     'cloudCover': 0.16,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.98},
#    {'time': 1560326400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.61,
#     'apparentTemperature': 81.74,
#     'dewPoint': 73.92,
#     'humidity': 0.86,
#     'pressure': 1015.23,
#     'windSpeed': 4.52,
#     'windGust': 5.6,
#     'windBearing': 141,
#     'cloudCover': 0.24,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.67},
#    {'time': 1560330000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 78.36,
#     'apparentTemperature': 79.94,
#     'dewPoint': 73.82,
#     'humidity': 0.86,
#     'pressure': 1015.16,
#     'windSpeed': 4.37,
#     'windGust': 5.48,
#     'windBearing': 143,
#     'cloudCover': 0.27,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.59},
#    {'time': 1560333600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 78.83,
#     'apparentTemperature': 82.2,
#     'dewPoint': 73.95,
#     'humidity': 0.85,
#     'pressure': 1015.26,
#     'windSpeed': 4.62,
#     'windGust': 5.95,
#     'windBearing': 144,
#     'cloudCover': 0.28,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.77},
#    {'time': 1560337200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 79.57,
#     'apparentTemperature': 83.75,
#     'dewPoint': 74.16,
#     'humidity': 0.84,
#     'pressure': 1015.47,
#     'windSpeed': 5.1,
#     'windGust': 6.76,
#     'windBearing': 142,
#     'cloudCover': 0.28,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.26},
#    {'time': 1560340800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 80.94,
#     'apparentTemperature': 86.32,
#     'dewPoint': 74.25,
#     'humidity': 0.8,
#     'pressure': 1015.73,
#     'windSpeed': 5.45,
#     'windGust': 7.35,
#     'windBearing': 142,
#     'cloudCover': 0.26,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 298.63},
#    {'time': 1560344400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 83.32,
#     'apparentTemperature': 90.19,
#     'dewPoint': 74.09,
#     'humidity': 0.74,
#     'pressure': 1016.12,
#     'windSpeed': 5.46,
#     'windGust': 7.49,
#     'windBearing': 144,
#     'cloudCover': 0.22,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 298.79},
#    {'time': 1560348000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 86.2,
#     'apparentTemperature': 94.08,
#     'dewPoint': 73.75,
#     'humidity': 0.67,
#     'pressure': 1016.59,
#     'windSpeed': 5.34,
#     'windGust': 7.41,
#     'windBearing': 147,
#     'cloudCover': 0.15,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 298.9},
#    {'time': 1560351600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 88.38,
#     'apparentTemperature': 96.6,
#     'dewPoint': 73.33,
#     'humidity': 0.61,
#     'pressure': 1016.87,
#     'windSpeed': 5.21,
#     'windGust': 7.25,
#     'windBearing': 149,
#     'cloudCover': 0.1,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 298.87},
#    {'time': 1560355200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0017,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 89.57,
#     'apparentTemperature': 97.71,
#     'dewPoint': 72.9,
#     'humidity': 0.58,
#     'pressure': 1016.82,
#     'windSpeed': 4.83,
#     'windGust': 6.96,
#     'windBearing': 144,
#     'cloudCover': 0.08,
#     'uvIndex': 10,
#     'visibility': 10,
#     'ozone': 298.67},
#    {'time': 1560358800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.009,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 90.32,
#     'apparentTemperature': 98.22,
#     'dewPoint': 72.47,
#     'humidity': 0.56,
#     'pressure': 1016.6,
#     'windSpeed': 3.98,
#     'windGust': 6.76,
#     'windBearing': 136,
#     'cloudCover': 0.07,
#     'uvIndex': 11,
#     'visibility': 10,
#     'ozone': 298.32},
#    {'time': 1560362400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0168,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 90.99,
#     'apparentTemperature': 98.79,
#     'dewPoint': 72.21,
#     'humidity': 0.54,
#     'pressure': 1016.31,
#     'windSpeed': 3.22,
#     'windGust': 6.7,
#     'windBearing': 132,
#     'cloudCover': 0.07,
#     'uvIndex': 11,
#     'visibility': 10,
#     'ozone': 297.63},
#    {'time': 1560366000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0193,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 91.77,
#     'apparentTemperature': 99.79,
#     'dewPoint': 72.21,
#     'humidity': 0.53,
#     'pressure': 1015.95,
#     'windSpeed': 3.08,
#     'windGust': 6.9,
#     'windBearing': 132,
#     'cloudCover': 0.11,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 296.31},
#    {'time': 1560369600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0245,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 91.39,
#     'apparentTemperature': 99.48,
#     'dewPoint': 72.38,
#     'humidity': 0.54,
#     'pressure': 1015.54,
#     'windSpeed': 3.31,
#     'windGust': 7.22,
#     'windBearing': 131,
#     'cloudCover': 0.17,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 294.8},
#    {'time': 1560373200,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.028,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 90.32,
#     'apparentTemperature': 98.43,
#     'dewPoint': 72.68,
#     'humidity': 0.56,
#     'pressure': 1015.3,
#     'windSpeed': 3.72,
#     'windGust': 7.56,
#     'windBearing': 132,
#     'cloudCover': 0.2,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 293.42},
#    {'time': 1560376800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0176,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 88.75,
#     'apparentTemperature': 96.94,
#     'dewPoint': 73.19,
#     'humidity': 0.6,
#     'pressure': 1015.33,
#     'windSpeed': 4.33,
#     'windGust': 7.7,
#     'windBearing': 139,
#     'cloudCover': 0.18,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 292.54},
#    {'time': 1560380400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0059,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 87.04,
#     'apparentTemperature': 95.26,
#     'dewPoint': 73.78,
#     'humidity': 0.65,
#     'pressure': 1015.52,
#     'windSpeed': 4.45,
#     'windGust': 7.7,
#     'windBearing': 141,
#     'cloudCover': 0.13,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.91},
#    {'time': 1560384000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0023,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 85.42,
#     'apparentTemperature': 93.41,
#     'dewPoint': 74.21,
#     'humidity': 0.69,
#     'pressure': 1015.8,
#     'windSpeed': 4.51,
#     'windGust': 7.53,
#     'windBearing': 141,
#     'cloudCover': 0.09,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.21},
#    {'time': 1560387600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 83.78,
#     'apparentTemperature': 91.05,
#     'dewPoint': 74.29,
#     'humidity': 0.73,
#     'pressure': 1016.27,
#     'windSpeed': 4.74,
#     'windGust': 7.13,
#     'windBearing': 143,
#     'cloudCover': 0.07,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 290.32},
#    {'time': 1560391200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 82.56,
#     'apparentTemperature': 89.03,
#     'dewPoint': 74.15,
#     'humidity': 0.76,
#     'pressure': 1016.86,
#     'windSpeed': 4.96,
#     'windGust': 6.63,
#     'windBearing': 149,
#     'cloudCover': 0.06,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 289.42},
#    {'time': 1560394800,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.5,
#     'apparentTemperature': 87.19,
#     'dewPoint': 74.02,
#     'humidity': 0.78,
#     'pressure': 1017.27,
#     'windSpeed': 5.04,
#     'windGust': 6.3,
#     'windBearing': 155,
#     'cloudCover': 0.05,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 288.48},
#    {'time': 1560398400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.7,
#     'apparentTemperature': 85.76,
#     'dewPoint': 73.95,
#     'humidity': 0.8,
#     'pressure': 1017.38,
#     'windSpeed': 5.08,
#     'windGust': 6.16,
#     'windBearing': 157,
#     'cloudCover': 0.06,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.6},
#    {'time': 1560402000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 80.16,
#     'apparentTemperature': 84.77,
#     'dewPoint': 73.93,
#     'humidity': 0.81,
#     'pressure': 1017.34,
#     'windSpeed': 5.13,
#     'windGust': 6.09,
#     'windBearing': 156,
#     'cloudCover': 0.07,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 286.78},
#    {'time': 1560405600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 79.72,
#     'apparentTemperature': 83.94,
#     'dewPoint': 73.9,
#     'humidity': 0.82,
#     'pressure': 1017.21,
#     'windSpeed': 5.1,
#     'windGust': 6.06,
#     'windBearing': 156,
#     'cloudCover': 0.08,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 286.21},
#    {'time': 1560409200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.04,
#     'apparentTemperature': 82.61,
#     'dewPoint': 73.83,
#     'humidity': 0.84,
#     'pressure': 1016.88,
#     'windSpeed': 4.87,
#     'windGust': 5.97,
#     'windBearing': 159,
#     'cloudCover': 0.08,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 285.95},
#    {'time': 1560412800,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.2,
#     'apparentTemperature': 79.78,
#     'dewPoint': 73.77,
#     'humidity': 0.86,
#     'pressure': 1016.47,
#     'windSpeed': 4.58,
#     'windGust': 5.89,
#     'windBearing': 161,
#     'cloudCover': 0.07,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 285.96},
#    {'time': 1560416400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.17,
#     'apparentTemperature': 79.76,
#     'dewPoint': 73.83,
#     'humidity': 0.87,
#     'pressure': 1016.32,
#     'windSpeed': 4.46,
#     'windGust': 5.95,
#     'windBearing': 163,
#     'cloudCover': 0.06,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 285.94},
#    {'time': 1560420000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.66,
#     'apparentTemperature': 81.9,
#     'dewPoint': 74.25,
#     'humidity': 0.86,
#     'pressure': 1016.64,
#     'windSpeed': 4.68,
#     'windGust': 6.22,
#     'windBearing': 162,
#     'cloudCover': 0.11,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 285.84},
#    {'time': 1560423600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 79.47,
#     'apparentTemperature': 83.73,
#     'dewPoint': 74.8,
#     'humidity': 0.86,
#     'pressure': 1017.25,
#     'windSpeed': 5.07,
#     'windGust': 6.57,
#     'windBearing': 159,
#     'cloudCover': 0.18,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 285.81},
#    {'time': 1560427200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 80.79,
#     'apparentTemperature': 86.49,
#     'dewPoint': 75.09,
#     'humidity': 0.83,
#     'pressure': 1017.76,
#     'windSpeed': 5.38,
#     'windGust': 6.96,
#     'windBearing': 156,
#     'cloudCover': 0.22,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 285.69},
#    {'time': 1560430800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 83.09,
#     'apparentTemperature': 90.42,
#     'dewPoint': 74.88,
#     'humidity': 0.76,
#     'pressure': 1018.14,
#     'windSpeed': 5.55,
#     'windGust': 7.54,
#     'windBearing': 152,
#     'cloudCover': 0.23,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 285.36},
#    {'time': 1560434400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 85.88,
#     'apparentTemperature': 94.25,
#     'dewPoint': 74.4,
#     'humidity': 0.69,
#     'pressure': 1018.47,
#     'windSpeed': 5.69,
#     'windGust': 8.21,
#     'windBearing': 148,
#     'cloudCover': 0.22,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 284.89},
#    {'time': 1560438000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 88.22,
#     'apparentTemperature': 96.86,
#     'dewPoint': 73.79,
#     'humidity': 0.63,
#     'pressure': 1018.63,
#     'windSpeed': 5.74,
#     'windGust': 8.5,
#     'windBearing': 143,
#     'cloudCover': 0.2,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 284.45},
#    {'time': 1560441600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 89.59,
#     'apparentTemperature': 97.83,
#     'dewPoint': 72.99,
#     'humidity': 0.58,
#     'pressure': 1018.54,
#     'windSpeed': 5.35,
#     'windGust': 7.96,
#     'windBearing': 138,
#     'cloudCover': 0.16,
#     'uvIndex': 10,
#     'visibility': 10,
#     'ozone': 284.16},
#    {'time': 1560445200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0088,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 90.79,
#     'apparentTemperature': 98.43,
#     'dewPoint': 72.09,
#     'humidity': 0.55,
#     'pressure': 1018.29,
#     'windSpeed': 4.31,
#     'windGust': 7.03,
#     'windBearing': 131,
#     'cloudCover': 0.11,
#     'uvIndex': 11,
#     'visibility': 10,
#     'ozone': 283.93},
#    {'time': 1560448800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0147,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 91.4,
#     'apparentTemperature': 98.7,
#     'dewPoint': 71.59,
#     'humidity': 0.53,
#     'pressure': 1017.98,
#     'windSpeed': 3.64,
#     'windGust': 6.54,
#     'windBearing': 112,
#     'cloudCover': 0.07,
#     'uvIndex': 12,
#     'visibility': 10,
#     'ozone': 283.37}]},
#  'daily': {'summary': 'Light rain today through Sunday, with high temperatures falling to 88°F on Sunday.',
#   'icon': 'rain',
#   'data': [{'time': 1560225600,
#     'summary': 'Rain in the evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560249877,
#     'sunsetTime': 1560298591,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0127,
#     'precipIntensityMax': 0.0719,
#     'precipIntensityMaxTime': 1560297600,
#     'precipProbability': 0.48,
#     'precipType': 'rain',
#     'temperatureHigh': 91.3,
#     'temperatureHighTime': 1560279600,
#     'temperatureLow': 78.36,
#     'temperatureLowTime': 1560330000,
#     'apparentTemperatureHigh': 102.13,
#     'apparentTemperatureHighTime': 1560279600,
#     'apparentTemperatureLow': 79.94,
#     'apparentTemperatureLowTime': 1560330000,
#     'dewPoint': 73.5,
#     'humidity': 0.73,
#     'pressure': 1016.03,
#     'windSpeed': 4.13,
#     'windGust': 8.59,
#     'windGustTime': 1560301200,
#     'windBearing': 84,
#     'cloudCover': 0.47,
#     'uvIndex': 8,
#     'uvIndexTime': 1560268800,
#     'visibility': 7.61,
#     'ozone': 299.96,
#     'temperatureMin': 73.64,
#     'temperatureMinTime': 1560250800,
#     'temperatureMax': 91.3,
#     'temperatureMaxTime': 1560279600,
#     'apparentTemperatureMin': 75.2,
#     'apparentTemperatureMinTime': 1560250800,
#     'apparentTemperatureMax': 102.13,
#     'apparentTemperatureMaxTime': 1560279600},
#    {'time': 1560312000,
#     'summary': 'Humid throughout the day and partly cloudy in the morning.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560336280,
#     'sunsetTime': 1560385011,
#     'moonPhase': 0.34,
#     'precipIntensity': 0.0054,
#     'precipIntensityMax': 0.028,
#     'precipIntensityMaxTime': 1560373200,
#     'precipProbability': 0.27,
#     'precipType': 'rain',
#     'temperatureHigh': 91.77,
#     'temperatureHighTime': 1560366000,
#     'temperatureLow': 78.17,
#     'temperatureLowTime': 1560416400,
#     'apparentTemperatureHigh': 99.79,
#     'apparentTemperatureHighTime': 1560366000,
#     'apparentTemperatureLow': 79.76,
#     'apparentTemperatureLowTime': 1560416400,
#     'dewPoint': 73.65,
#     'humidity': 0.71,
#     'pressure': 1015.98,
#     'windSpeed': 4.63,
#     'windGust': 7.84,
#     'windGustTime': 1560312000,
#     'windBearing': 140,
#     'cloudCover': 0.15,
#     'uvIndex': 11,
#     'uvIndexTime': 1560358800,
#     'visibility': 10,
#     'ozone': 295.95,
#     'temperatureMin': 78.36,
#     'temperatureMinTime': 1560330000,
#     'temperatureMax': 91.77,
#     'temperatureMaxTime': 1560366000,
#     'apparentTemperatureMin': 79.94,
#     'apparentTemperatureMinTime': 1560330000,
#     'apparentTemperatureMax': 99.79,
#     'apparentTemperatureMaxTime': 1560366000},
#    {'time': 1560398400,
#     'summary': 'Humid throughout the day and partly cloudy starting in the evening.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560422685,
#     'sunsetTime': 1560471430,
#     'moonPhase': 0.38,
#     'precipIntensity': 0.0056,
#     'precipIntensityMax': 0.0197,
#     'precipIntensityMaxTime': 1560466800,
#     'precipProbability': 0.33,
#     'precipType': 'rain',
#     'temperatureHigh': 91.77,
#     'temperatureHighTime': 1560452400,
#     'temperatureLow': 78.3,
#     'temperatureLowTime': 1560502800,
#     'apparentTemperatureHigh': 99.34,
#     'apparentTemperatureHighTime': 1560452400,
#     'apparentTemperatureLow': 79.84,
#     'apparentTemperatureLowTime': 1560502800,
#     'dewPoint': 73.56,
#     'humidity': 0.71,
#     'pressure': 1017.46,
#     'windSpeed': 2.96,
#     'windGust': 9.86,
#     'windGustTime': 1560477600,
#     'windBearing': 104,
#     'cloudCover': 0.2,
#     'uvIndex': 12,
#     'uvIndexTime': 1560448800,
#     'visibility': 9.81,
#     'ozone': 283.1,
#     'temperatureMin': 78.17,
#     'temperatureMinTime': 1560416400,
#     'temperatureMax': 91.77,
#     'temperatureMaxTime': 1560452400,
#     'apparentTemperatureMin': 79.76,
#     'apparentTemperatureMinTime': 1560416400,
#     'apparentTemperatureMax': 99.34,
#     'apparentTemperatureMaxTime': 1560452400},
#    {'time': 1560484800,
#     'summary': 'Humid and mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560509090,
#     'sunsetTime': 1560557849,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0018,
#     'precipIntensityMax': 0.0062,
#     'precipIntensityMaxTime': 1560564000,
#     'precipProbability': 0.21,
#     'precipType': 'rain',
#     'temperatureHigh': 91.26,
#     'temperatureHighTime': 1560538800,
#     'temperatureLow': 79.14,
#     'temperatureLowTime': 1560589200,
#     'apparentTemperatureHigh': 100.59,
#     'apparentTemperatureHighTime': 1560538800,
#     'apparentTemperatureLow': 82.81,
#     'apparentTemperatureLowTime': 1560589200,
#     'dewPoint': 74.03,
#     'humidity': 0.72,
#     'pressure': 1017.33,
#     'windSpeed': 9.18,
#     'windGust': 19.61,
#     'windGustTime': 1560567600,
#     'windBearing': 66,
#     'cloudCover': 0.52,
#     'uvIndex': 8,
#     'uvIndexTime': 1560528000,
#     'visibility': 10,
#     'ozone': 279.08,
#     'temperatureMin': 78.3,
#     'temperatureMinTime': 1560502800,
#     'temperatureMax': 91.26,
#     'temperatureMaxTime': 1560538800,
#     'apparentTemperatureMin': 79.84,
#     'apparentTemperatureMinTime': 1560502800,
#     'apparentTemperatureMax': 100.59,
#     'apparentTemperatureMaxTime': 1560538800},
#    {'time': 1560571200,
#     'summary': 'Humid and overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1560595497,
#     'sunsetTime': 1560644266,
#     'moonPhase': 0.45,
#     'precipIntensity': 0.0076,
#     'precipIntensityMax': 0.0315,
#     'precipIntensityMaxTime': 1560643200,
#     'precipProbability': 0.47,
#     'precipType': 'rain',
#     'temperatureHigh': 89.67,
#     'temperatureHighTime': 1560618000,
#     'temperatureLow': 78.14,
#     'temperatureLowTime': 1560672000,
#     'apparentTemperatureHigh': 98.15,
#     'apparentTemperatureHighTime': 1560618000,
#     'apparentTemperatureLow': 79.76,
#     'apparentTemperatureLowTime': 1560672000,
#     'dewPoint': 73.96,
#     'humidity': 0.73,
#     'pressure': 1016.55,
#     'windSpeed': 10.22,
#     'windGust': 20.79,
#     'windGustTime': 1560654000,
#     'windBearing': 88,
#     'cloudCover': 0.95,
#     'uvIndex': 6,
#     'uvIndexTime': 1560618000,
#     'visibility': 9.12,
#     'ozone': 279.23,
#     'temperatureMin': 79.14,
#     'temperatureMinTime': 1560589200,
#     'temperatureMax': 89.67,
#     'temperatureMaxTime': 1560618000,
#     'apparentTemperatureMin': 82.81,
#     'apparentTemperatureMinTime': 1560589200,
#     'apparentTemperatureMax': 98.15,
#     'apparentTemperatureMaxTime': 1560618000},
#    {'time': 1560657600,
#     'summary': 'Light rain starting in the afternoon, continuing until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560681904,
#     'sunsetTime': 1560730683,
#     'moonPhase': 0.48,
#     'precipIntensity': 0.0154,
#     'precipIntensityMax': 0.0443,
#     'precipIntensityMaxTime': 1560711600,
#     'precipProbability': 0.66,
#     'precipType': 'rain',
#     'temperatureHigh': 88.4,
#     'temperatureHighTime': 1560704400,
#     'temperatureLow': 77.21,
#     'temperatureLowTime': 1560762000,
#     'apparentTemperatureHigh': 96.48,
#     'apparentTemperatureHighTime': 1560704400,
#     'apparentTemperatureLow': 78.67,
#     'apparentTemperatureLowTime': 1560762000,
#     'dewPoint': 73.96,
#     'humidity': 0.76,
#     'pressure': 1016.04,
#     'windSpeed': 9.92,
#     'windGust': 21.91,
#     'windGustTime': 1560661200,
#     'windBearing': 99,
#     'cloudCover': 0.8,
#     'uvIndex': 8,
#     'uvIndexTime': 1560708000,
#     'visibility': 9.49,
#     'ozone': 287.47,
#     'temperatureMin': 78.14,
#     'temperatureMinTime': 1560672000,
#     'temperatureMax': 88.4,
#     'temperatureMaxTime': 1560704400,
#     'apparentTemperatureMin': 79.76,
#     'apparentTemperatureMinTime': 1560672000,
#     'apparentTemperatureMax': 96.48,
#     'apparentTemperatureMaxTime': 1560704400},
#    {'time': 1560744000,
#     'summary': 'Humid throughout the day and mostly cloudy until evening.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560768312,
#     'sunsetTime': 1560817099,
#     'moonPhase': 0.52,
#     'precipIntensity': 0.0079,
#     'precipIntensityMax': 0.0296,
#     'precipIntensityMaxTime': 1560805200,
#     'precipProbability': 0.56,
#     'precipType': 'rain',
#     'temperatureHigh': 89.49,
#     'temperatureHighTime': 1560801600,
#     'temperatureLow': 77.68,
#     'temperatureLowTime': 1560844800,
#     'apparentTemperatureHigh': 97.41,
#     'apparentTemperatureHighTime': 1560801600,
#     'apparentTemperatureLow': 79.05,
#     'apparentTemperatureLowTime': 1560844800,
#     'dewPoint': 73.34,
#     'humidity': 0.74,
#     'pressure': 1016.43,
#     'windSpeed': 6.96,
#     'windGust': 17.81,
#     'windGustTime': 1560744000,
#     'windBearing': 105,
#     'cloudCover': 0.56,
#     'uvIndex': 6,
#     'uvIndexTime': 1560794400,
#     'visibility': 9.89,
#     'ozone': 289.29,
#     'temperatureMin': 77.21,
#     'temperatureMinTime': 1560762000,
#     'temperatureMax': 89.49,
#     'temperatureMaxTime': 1560801600,
#     'apparentTemperatureMin': 78.67,
#     'apparentTemperatureMinTime': 1560762000,
#     'apparentTemperatureMax': 97.41,
#     'apparentTemperatureMaxTime': 1560801600},
#    {'time': 1560830400,
#     'summary': 'Humid throughout the day and partly cloudy starting in the afternoon.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560854721,
#     'sunsetTime': 1560903515,
#     'moonPhase': 0.55,
#     'precipIntensity': 0.0074,
#     'precipIntensityMax': 0.0321,
#     'precipIntensityMaxTime': 1560880800,
#     'precipProbability': 0.37,
#     'precipType': 'rain',
#     'temperatureHigh': 90.41,
#     'temperatureHighTime': 1560888000,
#     'temperatureLow': 79.37,
#     'temperatureLowTime': 1560931200,
#     'apparentTemperatureHigh': 99.17,
#     'apparentTemperatureHighTime': 1560888000,
#     'apparentTemperatureLow': 82.88,
#     'apparentTemperatureLowTime': 1560931200,
#     'dewPoint': 73.24,
#     'humidity': 0.71,
#     'pressure': 1016.58,
#     'windSpeed': 4.86,
#     'windGust': 10.5,
#     'windGustTime': 1560902400,
#     'windBearing': 92,
#     'cloudCover': 0.32,
#     'uvIndex': 10,
#     'uvIndexTime': 1560877200,
#     'visibility': 9.79,
#     'ozone': 299.88,
#     'temperatureMin': 77.68,
#     'temperatureMinTime': 1560844800,
#     'temperatureMax': 90.41,
#     'temperatureMaxTime': 1560888000,
#     'apparentTemperatureMin': 79.05,
#     'apparentTemperatureMinTime': 1560844800,
#     'apparentTemperatureMax': 99.17,
#     'apparentTemperatureMaxTime': 1560888000}]},
#  'flags': {'sources': ['nearest-precip',
#    'cmc',
#    'gfs',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 3.838,
#   'units': 'us'},
#  'offset': -4}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*
